# %%
import pickle
import matplotlib.pyplot as plt

mse_train_1 = pickle.load(open('mse_train_human_intestine.pkl', 'rb'))
mse_train_2 = pickle.load(open('mse_train_human_myocardial_infarction.pkl', 'rb'))

mse_valid_1 = pickle.load(open('mse_valid_human_intestine.pkl', 'rb'))
mse_valid_2 = pickle.load(open('mse_valid_human_myocardial_infarction.pkl', 'rb'))

ax = plt.gca()  # get current axes
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# plt.plot(mse_train_1+mse_train_2)
# plt.savefig('stformer_mse_train.pdf')

plt.plot(mse_valid_1+mse_valid_2)
plt.savefig('stformer_mse_valid.pdf')

# %%
mse_train = pickle.load(open('../../scfoundation/fine-tuning/mse/mse_train_human_myocardial_infarction.pkl', 'rb'))

mse_valid = pickle.load(open('../../scfoundation/fine-tuning/mse/mse_valid_human_myocardial_infarction.pkl', 'rb'))

ax = plt.gca()  # get current axes
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# plt.plot(mse_train)
# plt.savefig('../../scfoundation/fine-tuning/mse/scf-ft_mse_train.pdf')

plt.plot(mse_valid)
plt.savefig('../../scfoundation/fine-tuning/mse/scf-ft_mse_valid.pdf')
